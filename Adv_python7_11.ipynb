# %% [markdown]
# 07/11/2025-------> Advaned python

# %%
if True:
    print("DS")
# Out:
# DS

# %%
if False:
    print("data")
print("Notes")
# Out:
# Notes

# %%
if False:
    print("DS")
else:
    print("FSDS")
# Out:
# FSDS

# %%
x=4
r=x%2
if r==0:
    print("Even NUm")
# Out:
# Even NUm

# %%
x=5
r=x%2
if r==0:
    print("Even NUm")
print('NOt Even')
# Out:
# NOt Even

# %%
x=5
r=x%2
if r == 0:
    print("Even NUm")

# %%
x=4
r=x%2
if r==1:
    print("Even NUm")
else:
    print("odd")
# Out:
# odd

# %%
## MULTIPLE IF

x=10
r=x%2
if r==0:
    print("Even NUm")
if r==1:
    print("odd")
# Out:
# Even NUm

# %% [markdown]
# Multiple if are not wriiten----> Bcs it checks the line which is not required

# %% [markdown]
# --->Decreses the performances
# ---->increases the memory

# %% [markdown]
# Nested If:

# %%
x=4
r=x%2
if r==0:
    print("Even NUm")
    if x>3:
        print("Greater")
else:
    print("not even")
# Out:
# Even NUm
# Greater

# %%
x=6
r=x%2
if r==0:
    print("Even NUm")
    if x>7:
        print("Greater")   ### else is not written so execute only if==0---> even
else:
    print("not even")
# Out:
# Even NUm

# %%
x=6
r=x%2
if r==0:
    print("Even NUm")
    
    if x>7:
        print("Greater")
    else:
        print("lesser")
        
else:
    print("not even")
# Out:
# Even NUm
# lesser

# %%
x=7
r=x%2
if r==0:
    print("Even NUm")
    
    if x>7:
        print("Greater")
    else:
        print("lesser")
        
else:
    print("not even")
# Out:
# not even

# %% [markdown]
# If elif else:

# %%
x=10
r=x%2
if r==0:
    print("Even NUm")
    
if r==1:
    print("odd")

if r==2:
    print("even")
    
if r==3:
    print("odd")
# Out:
# Even NUm

# %%
r=10

if r==0:
    print("0")
    
elif r==1:
    print("one")

elif r==2:
    print("two")
    
elif r==3:
    print("3")
    
else:
    print('not available')
# Out:
# not available

# %%
r=3

if r==0:
    print("0")
    
elif r==1:
    print("one")

elif r==2:
    print("two")
    
elif r==3:
    print("Aavilbe")
    
else:
    print('not available')
# Out:
# Aavilbe

# %%
age=20

if age>=18:
    print("can work")
# Out:
# can work

# %%
age = int(input("enter the age: "))

if age==15:
    print("should be in 10 th class")
    
elif age<=20:
    print('study inter')
    
else:
    print('should work')
# Out:
# study inter

# %% [markdown]
# 10/11/2025------>
