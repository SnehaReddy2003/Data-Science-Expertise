# %% [markdown]
# 05/11/2025---> Country GDP Analysis(PANDAS work shop)

# %% [markdown]
# #shape

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as pyplot
import seaborn as sns

# %% [markdown]
# read the excel

# %%
stats=pd.read_excel(r'C:\Users\SNEHA\OneDrive\Desktop\DS_My notes\data.xlsx')
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 stats.rows
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.shape   ### 195rows, 5col
# Out:
# (195, 5)

# %%
stats.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
stats.isna()       ###isnull(), isna() both are same
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
stats.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
stats.dtypes   ### country name ---> caterogy data , by default sys considered as object
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
stats.info  ### infomation of the data frames
# Out:
# <bound method DataFrame.info of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.info()   ## memory usage: 7.7+ KB ---> data increases memory size also increaes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.head(2)    ## top 2 rows
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
stats.tail(2)    ## bottom 2 rows
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats['CountryName']   ## only the column needed i.e country name (read only specific column)
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
stats[:]    ## can use the slicing for the printing entire values
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[['CountryName']['BirthRate']]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_21088\384927957.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   stats[['CountryName']['BirthRate']]
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_21088\384927957.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   stats[['CountryName']['BirthRate']]
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_21088\384927957.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   stats[['CountryName']['BirthRate']]
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_21088\384927957.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ...

# %%
stats[['InternetUsers','BirthRate']]  ## read multiple columns which are specified
# Out:
#      InternetUsers  BirthRate
# 0             78.9     10.244
# 1              5.9     35.253
# 2             19.1     45.985
# 3             57.2     12.877
# 4             88.0     11.044
# ..             ...        ...
# 190           20.0     32.947
# 191           46.5     20.850
# 192            2.2     42.394
# 193           15.4     40.471
# 194           18.5     35.715
#
# [195 rows x 2 columns]

# %% [markdown]
# SPLIT the dtatset to numerical

# %%
stats_numeric_data=stats[['InternetUsers','BirthRate']]

# %%
stats_categorical_data=stats[['IncomeGroup','CountryName']]

# %% [markdown]
# Slicing

# %%
stats[:6]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
stats[3:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
stats[3:10]   ## starts from 3 to n-1
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[0:20:5]    ### step count
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244          78.90          High income
# 5    Argentina         ARG     17.716          59.90          High income
# 10  Azerbaijan         AZE     18.300          58.70  Upper middle income
# 15  Bangladesh         BGD     20.142           6.63  Lower middle income

# %%
stats[50:100]   ## records from 50 to 100 (100-1=99)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 50                Ecuador         ECU     21.070      40.353684
# 51       Egypt, Arab Rep.         EGY     28.032      29.400000
# 52                Eritrea         ERI     34.800       0.900000
# 53                  Spain         ESP      9.100      71.635000
# 54                Estonia         EST     10.300      79.400000
# 55               Ethiopia         ETH     32.925       1.900000
# 56                Finland         FIN     10.700      91.514400
# 57                   Fiji         FJI     20.463      37.100000
# 58                 France         FRA     12.300      81.919800
# 59  Micronesia, Fed. Sts.         FSM     23.511      27.800000
# 60                  Gabon         GAB     30.555       9.200000
# 61         United Kingdom         GBR     12.200      89.844100
# 62                Georgia         GEO     13.332      43.300000
# 63                  Ghana         GHA     33.131      12.300000
# ...

# %% [markdown]
# 06/11/2025

# %%
stats.describe()   ### describe()---->descriptive statisctics
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
stats.describe().transpose()   ### descriptive changes to rows to column and vice versa
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
stats_numeric_data.describe()
# Out:
#        InternetUsers   BirthRate
# count     195.000000  195.000000
# mean       42.076471   21.469928
# std        29.030788   10.605467
# min         0.900000    7.900000
# 25%        14.520000   12.120500
# 50%        41.000000   19.680000
# 75%        66.225000   29.759500
# max        96.546800   49.661000

# %%
stats_categorical_data.describe()
# Out:
#         IncomeGroup CountryName
# count           195         195
# unique            4         195
# top     High income       Aruba
# freq             67           1

# %%
stats.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
stats['BirthRate'] * stats['InternetUsers']
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
## stats---> is a dataframe

# %% [markdown]
# Add a column

# %%
stats['myCalc']=stats['BirthRate'] * stats['InternetUsers']    ### adding the new column in the exixting sheet

# %%
stats.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup    myCalc
# 0        Aruba         ABW     10.244           78.9  High income  808.2516
# 1  Afghanistan         AFG     35.253            5.9   Low income  207.9927

# %% [markdown]
# Drop the column

# %%
len(stats.columns)
# Out:
# 6

# %%
stats= stats.drop('myCalc',axis=1)

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# axis 0---> rows

# %% [markdown]
# axis 1---> columns

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats['InternetUsers']<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[stats['InternetUsers']<2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(stats[stats['InternetUsers']<2])
# Out:
# 9

# %%
stats[stats['BirthRate']>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
len(stats[stats['BirthRate']>40])
# Out:
# 12

# %%
stats[(stats.InternetUsers <2 )& (stats.BirthRate > 40 )]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats[stats.IncomeGroup=='Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
stats[stats.IncomeGroup=='High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
stats.IncomeGroup.unique
# Out:
# <bound method Series.unique of 0              High income
# 1               Low income
# 2      Upper middle income
# 3      Upper middle income
# 4              High income
#               ...
# 190    Lower middle income
# 191    Upper middle income
# 192             Low income
# 193    Lower middle income
# 194             Low income
# Name: IncomeGroup, Length: 195, dtype: object>

# %%
import matplotlib.pyplot as plt

# %%
stats['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1=plt.distplot(stats['InternetUsers'])   ### 'distplot' is not avilable in matplotlib
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 vis1=plt.distplot(stats['InternetUsers'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'distplot'

# %%
vis1=sns.distplot(stats['InternetUsers'])
plt.show()

### peak -- 0-20; lowest-- 80-100
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# univariate analysis---> plot the garph using 1 varaibale using one column for the above graph

# %%
vis1=sns.displot(stats['InternetUsers'])
plt.show()

# %%
vis3=sns.distplot(stats['InternetUsers'],bins=15)
plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Box plot

# %%
vis4=sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate')
plt.show()

#outliers from below is 3

# %% [markdown]
# from the garph the upper lin efor all the boxes is max;
# lower -- min
# middle -- is mean or Avg

# %% [markdown]
# Bivariate ---> uses two 2 varaibles

# %% [markdown]
# Income grp ----> low, high, lowwe middle income, middle income, lower upper middle incom

# %% [markdown]
# Out lier ---> the data is out of box , out of dataset

# %% [markdown]
# Handling outliers:
# using probabaility

# %% [markdown]
# quartile : lower Q1 and upperQ3

# %%
vis5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate')
plt.show()

## BI-VAriate plot

# %%
vis5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',fit_reg=False)
plt.show()

## line disappear

# %%
vis5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',fit_reg=True,hue='IncomeGroup')
plt.show()

### HUE ----> gruoping color

# %% [markdown]
# HUE ---->  describe colors forthe attribute

# %%
vis5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',z='CountryCode', fit_reg=True,hue='IncomeGroup')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 vis5=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',z='CountryCode', fit_reg=True,hue='IncomeGroup')
#       2 plt.show()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# TypeError: lmplot() got an unexpected keyword argument 'z'
